# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusMaartinS/pythonFag/blob/main/4_Tipos_de_variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tipos de variáveis
#
# Em Python, o tipo de uma variável é definido no momento de sua atribuição. Para observarmos o tipo de uma variável, utilizamos a função `type()`
#
# **Exemplo**
# ```python
# a = 10
# type(a)
# ```

# %%
a = "b"
type(a)
# Out:
# str

# %% [markdown]
# Existem diversos tipos de dados presentes nativamente em Python.
#
# ## `int` e `float`
#
#
# ### Exercício
# Observe o tipo das seguintes variáveis
# ```python
# inteiro=10
# type(inteiro)
#
# real=3.5
# type(real)
# ```

# %%
real=3.5
type(real)
# Out:
# float

# %% [markdown]
# Os tipos de dados `int` e `float` permitem que sejam realizados operações matemáticas sobre eles, como adição, subtração e divisão. Ambos os tipos permitem o armazenamento de números positivos e negativos, porém o tipo `float` opera utilizando *ponto flutuante*, ou seja, permite que números reais sejam armazenados.
#
# A diferença na definição da variável se ela será um `int` ou `float`, é dado pelo uso do `.`, que separa as casas decimais.

# %%
# 1,2,3,4,5
# 1.2 , 1.34 , 1.0000000000123 , 3.1415

# %% [markdown]
# ### Arredondamento
#
# Para arredondar valores `float`, pode-se utilizar a função `round()`.
#
# **Sintaxe**
# ```python
# round(valor, num_casas)
# ```
# onde:
# - `valor`: valor a ser arredondado
# - `num_casas`: número de casas decimais a ser utilizado (parâmetro opcional)
#
# **Exemplo**
# ```python
# round(2.5) #2 (int)
# round(2.5, 2) #2.5 (float)
# round(2.5, 0) #2.0 (float)
# round(5.00002, 3) #5.0 (float)
# ```
#
# ### Apresentando um número fixo de casas decimais
# Para que seja possível apresentar um número definido de casas decimais independente do arredondamente, pode-se utilizar a saída formatada de uma *string*.
#
# **Exemplo**
# Para apresentar o valor 5.0, com duas casas decimais:
#
# ```python
# val = 5.0
# print(f'{val:.2f}') #Saída: 5.00
# ```
#
# Observe que:
# - o `f` antes das aspas indica que a *string* será formatada.
# - as `{}` indicam que aquele conteúdo será substituído por um valor.
# - `:`: separador entre a variável e as informações de formatação.
# - `.2`: número de casas decimais. Neste caso, duas.
# - `f` : indica que é um float.

# %%
valor = 3.99999999
print(f"o valor é: {valor:.2f}")
# Out:
# o valor é: 4.00

# %%
valor = 5.00049
valor_arrend = round(valor, 3)
result = valor_arrend * 2
print(f"result é: {result:.3f}")
# Out:
# result é: 10.000

# %%
valor = 5.00049
result = valor * 2
print(f"result é: {result:.3f}")
# Out:
# result é: 10.001

# %% [markdown]
# **Atividade**
# - Qual é a diferença entre a função `round()` e a saída utilizando *string* formatada?

# %% [markdown]
# ## `bool`
#
# O tipo de dado `bool` permite armazenar um valor *booleano*, ou seja, verdadeiro (*True*) ou falso (*False*). Este tipo de variável permite apenas estes dois valores.
#
# **Atenção**
# >Os valores **True** e **False** possuem letra inicial maiúscula.
#
# **Exemplo**
# Considere que existe uma variável que registra se uma porta e uma janela estão abertas ou fechadas. Em seguida, observe o tipo de dado dessas variáveis.
# ```python
# portaAberta = True
# type(portaAberta)
#
# janelaAberta = False
# type(janelaAberta)
# ```

# %%
portaAberta = True
print(type(portaAberta))

janelaAberta = False
print(type(janelaAberta))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## `bool`
#
# O tipo de dado `bool` permite armazenar um valor *booleano*, ou seja, verdadeiro (*True*) ou falso (*False*). Este tipo de variável permite apenas estes dois valores.
#
# **Atenção**
# >Os valores **True** e **False** possuem letra inicial maiúscula.
#
# **Exemplo**
# Considere que existe uma variável que registra se uma porta e uma janela estão abertas ou fechadas. Em seguida, observe o tipo de dado dessas variáveis.
# ```python
# portaAberta = True
# type(portaAberta)
#
# janelaAberta = False
# type(janelaAberta)
# ```

# %% [markdown]
# ## `str`
#
# O tipol de dado `str` é utilizado para representar uma sequência de caracteres, ou *string*.
#
# Para que o interpretador Python reconheça que o dado é uma *string*, deve-se colocar a sequência de caracteres entre aspas (`'`) .
#
# **Exemplo**
# Considere variáveis que armazenam o país e o estado. Em seguida, observe o tipo da variável.
# ```python
# pais='Brasil'
# type(pais)
#
# estado='Santa Catarina'
# type(estado)
# ```
#
# **Anotação**
# >Em python, uma *string* também pode ser delimitada utilizando aspas duplas (`"`), e seu funcionamento ocorrerá da mesma forma. Porém, é uma convenção entre desenvolvedores a utilização das aspas simples, como utilizado no exemplo.

# %%
exemplo='texto qualquer \'com aspas duplas\' \n no meio'
print(exemplo)
# Out:
# texto qualquer 'com aspas duplas'
#  	 no meio

# %% [markdown]
# ## Conversões de tipos de dados
# Para converter um tipo de dado a outro pode-se utilizar funções que possuem o mesmo nome do tipo de dado.
# ```python
# int()
# float()
# str()
# bool()
# ```

# %% [markdown]
# **Atividade**
#
# Observe o conteúdo e tipo de dado de cada uma das variáveis utilizadas abaixo.
# ```python
# ni = 4
# nf = float(ni)
# ns = str(ni)
# ```
# O quê ocorreu com os tipos de dados?

# %%
ni = 4
print("ni:",ni)
print("type ni:",type(ni))
nf = float(ni)
print("ni:",nf)
print("type ni:",type(nf))
ns = str(ni)
print("ni:",ns)
print("type ni:",type(ns))
# Out:
# ni: 4
# type ni: <class 'int'>
# ni: 4.0
# type ni: <class 'float'>
# ni: 4
# type ni: <class 'str'>

# %% [markdown]
# **Atividade**
#
# Observe o conteúdo e tipo de dado de cada uma das variáveis utilizadas abaixo.
# ```python
# nf = 4.7
# ni = int(nf)
# ns = str(nf)
# ```
# O quê ocorreu com os tipos de dados?

# %%
nf = 4.999
print(nf)
ni = int(nf)
print(ni)
ns = str(nf)
print(ns)
# Out:
# 4.999
# 4
# 4.999

# %% [markdown]
# **Atividade**
#
# Observe o conteúdo e tipo de dado de cada uma das variáveis utilizadas abaixo.
# ```python
# ns = '4.7'
# ni = float(ns)
# ni = int(ns)
# ```
# O quê ocorreu com os tipos de dados?

# %%
ns = '4.7'
print(ns) # str 4.7
nf = float(ns)
print(nf) # float 4.7
ni = int(ns)
print(ni) # espero erro porque nao consegue fazer o cast de str para int quando nao é um int literal
# Out:
# 4.7
# 4.7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_571/1783991914.py in <cell line: 0>()
#       3 nf = float(ns)
#       4 print(nf) # float 4.7
# ----> 5 ni = int(ns)
#       6 print(ni) # espero erro porque nao consegue fazer o cast de str para int quando nao é um int literal
#
# ValueError: invalid literal for int() with base 10: '4.7'

# %%
ns = '4.7'
print(ns)
nf = float(ns)
print(nf)
ni = int(nf)
print(ni)
# Out:
# 4.7
# 4.7
# 4

# %% [markdown]
# **Atividade**
#
# Observe o conteúdo e tipo de dado de cada uma das variáveis utilizadas abaixo.
# ```py
# nb = True
# ns = str(nb)
# nf = float(nb)
# ni = int(nb)
# ```
# O quê ocorreu com os tipos de dados?

# %%
nb = True
print(f"tipo de nb: {type(nb)}\nvalor de nb: {nb}")
ns = str(nb)
print(f"tipo de ns: {type(ns)}\nvalor de ns: {ns}")
nf = float(nb)
print(f"tipo de nf: {type(nf)}\nvalor de nf: {nf}")
ni = int(nb)
print(f"tipo de ni: {type(ni)}\nvalor de ni: {ni}")
# Out:
# tipo de nb: <class 'bool'>
# valor de nb: True
# tipo de ns: <class 'str'>
# valor de ns: True
# tipo de nf: <class 'float'>
# valor de nf: 1.0
# tipo de ni: <class 'int'>
# valor de ni: 1

# %%
nb = False
print(f"tipo de nb: {type(nb)}\nvalor de nb: {nb}")
ns = str(nb)
print(f"tipo de ns: {type(ns)}\nvalor de ns: {ns}")
nf = float(nb)
print(f"tipo de nf: {type(nf)}\nvalor de nf: {nf}")
ni = int(nb)
print(f"tipo de ni: {type(ni)}\nvalor de ni: {ni}")
# Out:
# tipo de nb: <class 'bool'>
# valor de nb: False
# tipo de ns: <class 'str'>
# valor de ns: False
# tipo de nf: <class 'float'>
# valor de nf: 0.0
# tipo de ni: <class 'int'>
# valor de ni: 0

# %% [markdown]
# **Atividade**
# - Realize um programa que calcula a soma de três valores digitados pelo usuário em uma mesma linha, com os valores separados por espaços.
#     - **Entrada**
#         - 2 3 5
#     - **Saída**
#         - 10
#
#     - Dica: Utilize o método `.split()` do tipo de dado `string`.

# %%
[val1, _, val3] = input("digite tres valores separados por espaços :").split()
print(int(val1) + int(val3))
# Out:
# digite tres valores separados por espaços :1 2 3
# 4
